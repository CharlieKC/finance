# %%
import pandas as pd

# %%
ticker = "GME"
url = f"http://openinsider.com/search?q={ticker}#results"
dfs = pd.read_html(url)
df = list(filter(lambda _df: "Value" in _df.columns, dfs))[0]

# %%
df
# Out:
#      X          Filing Date  Trade Date Ticker         Insider Name  \
# 0  NaN  2021-06-24 16:33:55  2021-06-23    GME          Grube James
# 1  NaN  2021-01-19 17:12:16  2021-01-15    GME     Fernandez Raul J
# 2  NaN  2021-01-15 16:15:21  2021-01-13    GME      Vrabeck Kathy P
# 3    M  2021-01-15 16:15:01  2021-01-13    GME     Fernandez Raul J
# 4  NaN  2021-01-15 16:14:40  2021-01-13    GME        Dunn Lizabeth
# 5    M  2021-01-14 18:59:02  2021-01-12    GME      Wolf Kurt James
# 6    M  2020-12-21 16:06:06  2020-12-17    GME           Cohen Ryan
# 7  NaN  2020-04-17 16:19:58  2020-04-17    GME  Sherman George E Jr
# 8  NaN  2020-04-17 11:45:21  2020-04-17    GME         Bell James A
# 9  NaN  2020-04-16 16:09:36  2020-04-15    GME      Koonin Steven R
#
#                  Title    Trade Type    Price      Qty    Owned  ΔOwn  \
# 0                  Dir      S - Sale  $217.78    -1900     2023  -48%
# 1                  Dir      S - Sale   $37.71    -3500    29289  -11%
# 2                  Dir      S - Sale   $27.99   -50000    79537  -39%
# 3                  Dir      S - Sale   $35.28   -34619    32789  -51%
# 4                  Dir      S - Sale   $31.34    -5000    57258   -8%
# 5                  Dir      S - Sale   $21.22  -810000   460289  -64%
# 6  See Footnote 1, 10%  P - Purchase   $15.51  1226400  9001000  +16%
# 7                  CEO  P - Purchase    $4.52    25000  1127762   +2%
# 8             EVP, CFO  P - Purchase    $5.00     4500   242596   +2%
# 9                  Dir      S - Sale    $5.36   -34396    25271  -58%
#
#           Value  1d  1w  1m  6m
# 0     -$413,782 NaN NaN NaN NaN
# 1     -$131,980 NaN NaN NaN NaN
# 2   -$1,399,341 NaN NaN NaN NaN
# 3   -$1,221,216 NaN NaN NaN NaN
# 4     -$156,700 NaN NaN NaN NaN
# 5  -$17,190,000 NaN NaN NaN NaN
# 6  +$19,025,878 NaN NaN NaN NaN
# 7     +$112,910 NaN NaN NaN NaN
# 8      +$22,500 NaN NaN NaN NaN
# 9     -$184,325 NaN NaN NaN NaN

# %%
# Would be interesting to see insider trading vs price chart

# %%
len(df)
# Out:
# 10
